# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Pandas Version:", pd.__version__)
print("NumPy Version:", np.__version__)

data = {
    "Fund": ["SBI Bluechip", "HDFC Top 100", "ICICI Bluechip"],
    "NAV": [95.5, 102.3, 88.7]
}

df = pd.DataFrame(data)

df
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Pandas Version: 3.0.3
# NumPy Version: 2.2.6
#              Fund    NAV
# 0    SBI Bluechip   95.5
# 1    HDFC Top 100  102.3
# 2  ICICI Bluechip   88.7

# %%
print("Bluestock Project Ready!")
# Out:
# Bluestock Project Ready!
